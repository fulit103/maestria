# %%
# import data
import pandas as pd

# read from xlsx    
df = pd.read_excel('data/clustering.xlsx')
df.head()
# Out:
#   COD_PERIODO  COD_UTP              TIPO_PRUEBA  PUNTAJE_ICFES  EDAD  \
# 0      2018-1       28  Pruebas Despues de 2014          390.0    18
# 1      2018-1       28  Pruebas Despues de 2014          344.0    17
# 2      2018-1       28  Pruebas Despues de 2014          337.0    18
# 3      2018-2       28  Pruebas Despues de 2014          370.0    18
# 4      2018-2       28  Pruebas Despues de 2014          330.0    19
#
#         ESTRATO       SEXO TIPO_COLEGIO                 ESTADO BA172 CB115  \
# 0        2-BAJO  Masculino      Privado  2. Permanece programa   4,6   3,7
# 1  3-MEDIO-BAJO   Femenino      Oficial  2. Permanece programa   4,2   3,2
# 2        2-BAJO  Masculino      Oficial  2. Permanece programa     4   1,8
# 3        2-BAJO  Masculino      Privado  2. Permanece programa   4,4   4,7
# 4        2-BAJO  Masculino      Privado  2. Permanece programa   4,4     4
#
#   IS193 IS142
# 0     5   3,9
# 1   4,8   4,9
# 2   3,6   3,6
# 3   4,7     5
# 4   3,3   4,4
